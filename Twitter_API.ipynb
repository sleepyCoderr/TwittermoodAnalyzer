# %%
import twitter_credentials
import numpy as np
import pandas as pd
import oauth2 as oauth
import json

from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, MetaData, Table, Column, ForeignKey
from sqlalchemy.ext.automap import automap_base
import os
from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)

from flask_sqlalchemy import SQLAlchemy
import pandas as pd
from pandas import Series
from textblob import TextBlob

# %%
consumer=oauth.Consumer(key=twitter_credentials.CONSUMER_KEY,secret=twitter_credentials.CONSUMER_SECRET)
access_token=oauth.Token(key=twitter_credentials.ACCESS_TOKEN,secret=twitter_credentials.ACCESS_TOKEN_SECRET)
client=oauth.Client(consumer,access_token)

# %%
print(client)
# Out:
# <oauth2.Client object at 0x000001C2D45F2AC8>

# %%
url="https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=realDonaldTrump&count=10&tweet_mode=extended"

# %%
response,data=client.request(url)

# %%
tweets=json.loads(data)
# TextBlob(tweet['full_text'])
df = pd.DataFrame(data=[tweet['full_text'] for tweet in tweets], columns=['Tweets'])
df['len'] = np.array([len(tweet['full_text']) for tweet in tweets])
df['sentiment'] = np.array([TextBlob(tweet['full_text']).sentiment.polarity for tweet in tweets])
# df['friends']=[tweet['followers_count'] for tweet in tweets]
df
# Out:
#                                               Tweets  len  sentiment
# 0  ...The Steel Barrier, or Wall, should have bee...  283  -0.039815
# 1  Humanitarian Crisis at our Southern Border. I ...  280  -0.212500
# 2  H1-B holders in the United States can rest ass...  276   0.400000
# 3  I often said during rallies, with little varia...  278   0.160644
# 4  When I took the Oath of Office.... https://t.c...   58   0.000000
# 5  We lose 300 Americans a week, 90% of which com...  138   0.000000
# 6  Will be interviewed at the Border by @seanhann...   85   0.500000
# 7              Dear Diary... https://t.co/NAuMaQW6fl   37   0.000000
# 8  From the Southern Border.... https://t.co/Vgsf...   52   0.000000
# 9  RT @SenateGOP: Why do we need border security?...  121   0.000000

# %%
print(df[df['sentiment'] ==-0.400000])
# Out:
#                                               Tweets  len  sentiment
# 7  RT @charliekirk11: Governor Ron DeSantis suspe...  140       -0.4

# %%
def name():
    for tweet in tweets:
        n=tweet['full_text']
        return

# %%
name()
# Out:
# '...The Steel Barrier, or Wall, should have been built by previous administrations long ago. They never got it done - I will. Without it, our Country cannot be safe. Criminals, Gangs, Human Traffickers, Drugs &amp; so much other big trouble can easily pour in. It can be stopped cold!'

# %%
get_files()
# Out:
# [{'created_at': 'Fri Jan 11 12:40:30 +0000 2019',
#   'id': 1083705208834834433,
#   'id_str': '1083705208834834433',
#   'full_text': 'H1-B holders in the United States can rest assured that changes are soon coming which will bring both simplicity and certainty to your stay, including a potential path to citizenship. We want to encourage talented and highly skilled people to pursue career options in the U.S.',
#   'truncated': False,
#   'display_text_range': [0, 276],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 57174875,
#    'friends_count': 45,
#    'listed_count': 98892,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 40192,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 14818,
#   'favorite_count': 60608,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Jan 11 12:05:00 +0000 2019',
#   'id': 1083696274182995969,
#   'id_str': '1083696274182995969',
#   'full_text': 'I often said during rallies, with little variation, that “Mexico will pay for the Wall.” We have just signed a great new Trade Deal with Mexico. It is Billions of Dollars a year better than the very bad NAFTA deal which it replaces. The difference pays for Wall many times over!',
#   'truncated': False,
#   'display_text_range': [0, 278],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 57174875,
#    'friends_count': 45,
#    'listed_count': 98892,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 40192,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 15848,
#   'favorite_count': 67609,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Jan 11 02:43:00 +0000 2019',
#   'id': 1083554843627868160,
#   'id_str': '1083554843627868160',
#   'full_text': 'When I took the Oath of Office.... https://t.co/GDhIqteKpv',
#   'truncated': False,
#   'display_text_range': [0, 34],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1083554750971502594,
#      'id_str': '1083554750971502594',
#      'indices': [35, 58],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1083554750971502594/pu/img/V0LLiT7QdWwlLekH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1083554750971502594/pu/img/V0LLiT7QdWwlLekH.jpg',
#      'url': 'https://t.co/GDhIqteKpv',
#      'display_url': 'pic.twitter.com/GDhIqteKpv',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1083554843627868160/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1083554750971502594,
#      'id_str': '1083554750971502594',
#      'indices': [35, 58],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1083554750971502594/pu/img/V0LLiT7QdWwlLekH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1083554750971502594/pu/img/V0LLiT7QdWwlLekH.jpg',
#      'url': 'https://t.co/GDhIqteKpv',
#      'display_url': 'pic.twitter.com/GDhIqteKpv',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1083554843627868160/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 50005,
#       'variants': [{'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1083554750971502594/pu/vid/320x180/OZ2Aw_maFvBbbBY8.mp4?tag=6'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1083554750971502594/pu/vid/1280x720/Ob0nqmegsKA5sKrs.mp4?tag=6'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1083554750971502594/pu/pl/r3ALkd6WQx_ZA7DN.m3u8?tag=6'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1083554750971502594/pu/vid/640x360/sgm3-B4SMn_P64uu.mp4?tag=6'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 57174875,
#    'friends_count': 45,
#    'listed_count': 98892,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 40192,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 22308,
#   'favorite_count': 76882,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Jan 11 02:42:46 +0000 2019',
#   'id': 1083554782923632640,
#   'id_str': '1083554782923632640',
#   'full_text': 'We lose 300 Americans a week, 90% of which comes through the Southern Border. These numbers will be DRASTICALLY REDUCED if we have a Wall!',
#   'truncated': False,
#   'display_text_range': [0, 138],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 57174875,
#    'friends_count': 45,
#    'listed_count': 98892,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 40192,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 19781,
#   'favorite_count': 88210,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Jan 11 01:45:54 +0000 2019',
#   'id': 1083540470570143750,
#   'id_str': '1083540470570143750',
#   'full_text': 'Will be interviewed at the Border by @seanhannity on @FoxNews tonight at 9:00. Enjoy!',
#   'truncated': False,
#   'display_text_range': [0, 85],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'seanhannity',
#      'name': 'Sean Hannity',
#      'id': 41634520,
#      'id_str': '41634520',
#      'indices': [37, 49]},
#     {'screen_name': 'FoxNews',
#      'name': 'Fox News',
#      'id': 1367531,
#      'id_str': '1367531',
#      'indices': [53, 61]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/OMxB0x7xC5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 57174875,
#    'friends_count': 45,
#    'listed_count': 98892,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 40192,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10000,
#   'favorite_count': 53928,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]
